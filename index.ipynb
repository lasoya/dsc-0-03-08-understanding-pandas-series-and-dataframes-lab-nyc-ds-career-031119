# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Your code here
new_df = df.rename(str.lower, axis='columns')
new_df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Change the Index to be the Line Names

# %%
#Your code here
new_index = new_df.set_index('linename')
new_index.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
# Your code here
old_index = new_index.reset_index()
old_index.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
# Your code here
df['Num_Lines'] = df.LINENAME.map(lambda x:len(x))
df.sort_values(by="Num_Lines", ascending=False)
# Out:
#           C/A  UNIT       SCP         STATION      LINENAME DIVISION  \
# 132292   R151  R033  00-00-00  TIMES SQ-42 ST  1237ACENQRSW      IRT
# 2686     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2673     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2674     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2675     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2676     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2677     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2678     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2679     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2680     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2681     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2682     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2683     A021  R032  01-00-01  TIMES SQ-42 ST  ACENQRS1237W      BMT
# ...

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.strip() #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS', 'Num_Lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here
df.DATE = pd.to_datetime(df.DATE)
df['Dayofweek'] = df.DATE.dt.dayofweek
grouped = df.groupby('Dayofweek').sum()
grouped.plot(kind='barh')

# %%
grouped = grouped.reset_index()
grouped.head()
# Out:
#    Dayofweek        ENTRIES         EXITS  Num_Lines  DayOfWeek
# 0          0  1114237052454  911938153513      76110          0
# 1          1  1143313287046  942230721477      77303      28772
# 2          2  1123655222441  920630864687      75713      56406
# 3          3  1122723988662  920691927110      76607      85341
# 4          4  1110224700078  906799065337      75573     112404

# %%
grouped['IsWeekend'] = grouped.Dayofweek.map({0:False,1:False,2:False,3:False,4:False,5:True,6:True})
wkend = grouped.groupby('IsWeekend').mean()
wkend[['ENTRIES', 'EXITS']].plot(kind='barh')

# %%
grouped #there are the same
# Out:
#    Dayofweek        ENTRIES         EXITS  Num_Lines  DayOfWeek  IsWeekend
# 0          0  1114237052454  911938153513      76110          0      False
# 1          1  1143313287046  942230721477      77303      28772      False
# 2          2  1123655222441  920630864687      75713      56406      False
# 3          3  1122723988662  920691927110      76607      85341      False
# 4          4  1110224700078  906799065337      75573     112404      False
# 5          5  1115661545514  909142081474      74725     138835       True
# 6          6  1192306179082  959223750461      75306     168486       True

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here
# for i in df['DayOfWeek']:
#     if int(df['DayOfWeek'][i]) == 0:
#         df['DayOfWeek'][i].sum()
#     elif int(df['DayOfWeek'][i]) == 1:
#         Monday = df['DayOfWeek'][i].sum()
#     elif int(df['DayOfWeek'][i]) == 2:
#         Tuesday = df['DayOfWeek'][i].sum()
#     elif int(df['DayOfWeek'][i]) == 3:
#         Wednesday = df['DayOfWeek'][i].sum()
#     elif int(df['DayOfWeek'][i]) == 4:
#         Thursday = df['DayOfWeek'][i].sum()
#     elif int(df['DayOfWeek'][i]) == 5:
#         Friday = df['DayOfWeek'][i].sum()
#     else:
#         Saturday = df['DayOfWeek'][i].sum()

# most = 0
# for i in df['DayOfWeek'].index:
#     if (df['DayOfWeek'][i].sum()) > most:
#         most = df['DayOfWeek'][i]
df.DayOfWeek.value_counts()
# Out:
# 1    28772
# 3    28447
# 0    28254
# 2    28203
# 4    28101
# 6    28081
# 5    27767
# Name: DayOfWeek, dtype: int64

# %%
dow = dict(df.DayOfWeek.value_counts())
dow
# Out:
# {1: 28772, 3: 28447, 0: 28254, 2: 28203, 4: 28101, 6: 28081, 5: 27767}

# %%
max_count = max(dow.values())
for k, v in dow.items():
    if v == max_count:
        print(k)
# Out:
# 1

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
dropped = df.drop(['C/A', 'UNIT', 'DIVISION'], axis=1)
dropped.head()
# Out:
#         SCP STATION LINENAME       DATE      TIME     DESC  ENTRIES    EXITS  \
# 0  02-00-00   59 ST  NQR456W 2018-08-25  00:00:00  REGULAR  6736067  2283184
# 1  02-00-00   59 ST  NQR456W 2018-08-25  04:00:00  REGULAR  6736087  2283188
# 2  02-00-00   59 ST  NQR456W 2018-08-25  08:00:00  REGULAR  6736105  2283229
# 3  02-00-00   59 ST  NQR456W 2018-08-25  12:00:00  REGULAR  6736180  2283314
# 4  02-00-00   59 ST  NQR456W 2018-08-25  16:00:00  REGULAR  6736349  2283384
#
#    Num_Lines  DayOfWeek
# 0          7          5
# 1          7          5
# 2          7          5
# 3          7          5
# 4          7          5
